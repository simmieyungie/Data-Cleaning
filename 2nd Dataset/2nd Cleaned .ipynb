# %%
import pandas as pd
import numpy as np

# %%
Cdata = pd.read_excel('2.-Badly-Structured-Sales-Data-2.xlsx')

# %%
Cdata
# Out:
#                Ship Mode First Class Unnamed: 2   Unnamed: 3  Same Day  \
# 0                Segment    Consumer  Corporate  Home Office  Consumer
# 1             Order Date         NaN        NaN          NaN       NaN
# 2    2013-03-14 00:00:00         NaN        NaN          NaN       NaN
# 3    2013-12-16 00:00:00         NaN        NaN          NaN       NaN
# 4    2013-06-02 00:00:00         NaN        NaN          NaN       NaN
# ..                   ...         ...        ...          ...       ...
# 819  2016-07-03 00:00:00         NaN        NaN          NaN       NaN
# 820  2016-03-28 00:00:00         NaN        NaN          NaN       NaN
# 821  2016-12-09 00:00:00         NaN        NaN          NaN       NaN
# 822  2016-11-04 00:00:00         NaN        NaN          NaN       NaN
# 823  2016-01-08 00:00:00         NaN        NaN          NaN       NaN
#
#     Unnamed: 5   Unnamed: 6 Second Class Unnamed: 8   Unnamed: 9  \
# ...

# %%
Cdata.columns
# Out:
# Index(['Ship Mode', 'First Class', 'Unnamed: 2', 'Unnamed: 3', 'Same Day',
#        'Unnamed: 5', 'Unnamed: 6', 'Second Class', 'Unnamed: 8', 'Unnamed: 9',
#        'Standard Class', 'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')

# %%
#Renaming the columns
Cdata.rename(columns = {'Ship Mode': 'Order Date' }, inplace = True)
Cdata.rename(columns = {'Unnamed: 2': 'First Class' }, inplace = True)
Cdata.rename(columns = {'Unnamed: 3': 'First Class' }, inplace = True)
Cdata.rename(columns = {'Unnamed: 5': 'Same Day' }, inplace = True)
Cdata.rename(columns = {'Unnamed: 6': 'Same Day' }, inplace = True)
Cdata.rename(columns = {'Unnamed: 8': 'Second Class' }, inplace = True)
Cdata.rename(columns = {'Unnamed: 9': 'Second Class' }, inplace = True)
Cdata.rename(columns = {'Unnamed: 11': 'Standard Class' }, inplace = True)
Cdata.rename(columns = {'Unnamed: 12': 'Standard Class' }, inplace = True)

# %%
Cdata
# Out:
#               Order Date First Class First Class  First Class  Same Day  \
# 0                Segment    Consumer   Corporate  Home Office  Consumer
# 1             Order Date         NaN         NaN          NaN       NaN
# 2    2013-03-14 00:00:00         NaN         NaN          NaN       NaN
# 3    2013-12-16 00:00:00         NaN         NaN          NaN       NaN
# 4    2013-06-02 00:00:00         NaN         NaN          NaN       NaN
# ..                   ...         ...         ...          ...       ...
# 819  2016-07-03 00:00:00         NaN         NaN          NaN       NaN
# 820  2016-03-28 00:00:00         NaN         NaN          NaN       NaN
# 821  2016-12-09 00:00:00         NaN         NaN          NaN       NaN
# 822  2016-11-04 00:00:00         NaN         NaN          NaN       NaN
# 823  2016-01-08 00:00:00         NaN         NaN          NaN       NaN
#
#       Same Day     Same Day Second Class Second Class Second Class  \
# ...

# %%
#extracting the first phase of the data to be cleaned
Cdata1 = Cdata.iloc[2:]

# %%
Cdata1
# Out:
#               Order Date First Class First Class First Class Same Day  \
# 2    2013-03-14 00:00:00         NaN         NaN         NaN      NaN
# 3    2013-12-16 00:00:00         NaN         NaN         NaN      NaN
# 4    2013-06-02 00:00:00         NaN         NaN         NaN      NaN
# 5    2013-10-21 00:00:00         NaN         NaN         NaN      NaN
# 6    2013-08-27 00:00:00         NaN         NaN         NaN      NaN
# ..                   ...         ...         ...         ...      ...
# 819  2016-07-03 00:00:00         NaN         NaN         NaN      NaN
# 820  2016-03-28 00:00:00         NaN         NaN         NaN      NaN
# 821  2016-12-09 00:00:00         NaN         NaN         NaN      NaN
# 822  2016-11-04 00:00:00         NaN         NaN         NaN      NaN
# 823  2016-01-08 00:00:00         NaN         NaN         NaN      NaN
#
#     Same Day Same Day Second Class Second Class Second Class Standard Class  \
# ...

# %%
#resetting the index
Cdata1.reset_index(drop= True, inplace = True)

# %%
#turning the columns into row
Cdata1 = pd.melt(Cdata1 , id_vars= ['Order Date'] , value_vars= ['First Class', 'First Class', 'First Class', 'Same Day',
       'Same Day', 'Same Day', 'Second Class', 'Second Class', 'Second Class',
       'Standard Class', 'Standard Class', 'Standard Class'], var_name = "Ship Mode", value_name = "Sales" )

# %%
Cdata1
# Out:
#       Order Date       Ship Mode Sales
# 0     2013-03-14     First Class   NaN
# 1     2013-12-16     First Class   NaN
# 2     2013-06-02     First Class   NaN
# 3     2013-10-21     First Class   NaN
# 4     2013-08-27     First Class   NaN
# ...          ...             ...   ...
# 29587 2016-07-03  Standard Class   NaN
# 29588 2016-03-28  Standard Class   NaN
# 29589 2016-12-09  Standard Class   NaN
# 29590 2016-11-04  Standard Class   NaN
# 29591 2016-01-08  Standard Class   NaN
#
# [29592 rows x 3 columns]

# %%
#extracting the second phase 
Cdata2 =Cdata.iloc[0:]

# %%
#making the first row the new colunm
Cdata2.columns= Cdata2.iloc[0]

# %%
#dropping the wanted rows
Cdata2.drop(0, inplace = True)
Cdata2.drop(1, inplace = True)

# %%
Cdata2.columns
# Out:
# Index(['Segment', 'Consumer', 'Corporate', 'Home Office', 'Consumer',
#        'Corporate', 'Home Office', 'Consumer', 'Corporate', 'Home Office',
#        'Consumer', 'Corporate', 'Home Office'],
#       dtype='object', name=0)

# %%
#Renaming the column
Cdata2.rename(columns= {'Segment':'Order Date'}, inplace = True)

# %%
#Resetting the index
Cdata2.reset_index(drop=True,inplace=True)

# %%
Cdata2 =  pd.melt(Cdata2 , id_vars= ['Order Date'] , value_vars= ['Consumer', 'Corporate', 'Home Office', 'Consumer',
       'Corporate', 'Home Office', 'Consumer', 'Corporate', 'Home Office',
       'Consumer', 'Corporate', 'Home Office'], var_name = "Segment", value_name = "Sales" )

# %%
Cdata2
# Out:
#       Order Date      Segment Sales
# 0     2013-03-14     Consumer   NaN
# 1     2013-12-16     Consumer   NaN
# 2     2013-06-02     Consumer   NaN
# 3     2013-10-21     Consumer   NaN
# 4     2013-08-27     Consumer   NaN
# ...          ...          ...   ...
# 39451 2016-07-03  Home Office   NaN
# 39452 2016-03-28  Home Office   NaN
# 39453 2016-12-09  Home Office   NaN
# 39454 2016-11-04  Home Office   NaN
# 39455 2016-01-08  Home Office   NaN
#
# [39456 rows x 3 columns]

# %%
#merging the two cleaned phases
Full = pd.merge(Cdata1, Cdata2, on = ('Order Date', 'Sales'))

# %%
Full
# Out:
#         Order Date       Ship Mode  Sales      Segment
# 0       2013-03-14     First Class    NaN     Consumer
# 1       2013-03-14     First Class    NaN     Consumer
# 2       2013-03-14     First Class    NaN     Consumer
# 3       2013-03-14     First Class    NaN     Consumer
# 4       2013-03-14     First Class    NaN     Consumer
# ...            ...             ...    ...          ...
# 2060083 2016-11-04  Standard Class  9.664  Home Office
# 2060084 2016-11-04  Standard Class  9.664  Home Office
# 2060085 2016-11-04  Standard Class  9.664  Home Office
# 2060086 2016-11-04  Standard Class  9.664  Home Office
# 2060087 2016-11-04  Standard Class  9.664  Home Office
#
# [2060088 rows x 4 columns]

# %%
#Dropping null values
Full.dropna(inplace = True )

# %%
#Droppping the duplicate but keeping thefirst
Full.drop_duplicates(subset =["Sales", "Order Date"], 
                     keep = 'first', inplace = True)

# %%
#resetting the index
Full.reset_index(drop=True,inplace=True)

# %%
#saving file as csv
Full.to_csv('Second_Cleaned.csv', index=False)
